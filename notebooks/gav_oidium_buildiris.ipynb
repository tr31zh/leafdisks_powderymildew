# %%
from sklearn.datasets import load_iris
import os

# %%
os.getcwd()
# Out:
# 'c:\\Users\\fmavianemac\\Documents\\Felicia\\Python\\thesis\\notebooks'

# %%
load_iris(
    as_frame=True
)[
    "data"
].to_csv(
    os.path.join("..", "data_in", "iris_row.csv"), 
    index=False, 
    sep=";"
)
